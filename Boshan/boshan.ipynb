# %%
import time
import pyodbc
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.72.42;DATABASE=FB_IMDB;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from FBComment order by PostNO,CommentNO asc")

CommentRows = cursor.fetchall()
print CommentRows[0].Message
# Out:
# For starters:He is papa Winchester :P

# %%
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.72.42;DATABASE=IMDb_MG;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from Opinion  order by P_N asc")

OpinionRows = cursor.fetchall()
print OpinionRows
# Out:
# [(u'possible', 0.0), (u'thriller', 0.0), (u'amaze', 0.0), (u'expect', 0.0), (u'ABIDE', 0.0), (u'ABILITY', 0.0), (u'ABLE', 0.0), (u'ABOUND', 0.0), (u'ACCEDE', 0.0), (u'ACCENTUATE', 0.0), (u'ACCEPT', 0.0), (u'ACCEPTABLE', 0.0), (u'ACCEPTANCE', 0.0), (u'ACCESSIBLE', 0.0), (u'ACCESSION', 0.0), (u'ACCLAIM', 0.0), (u'ACCLAMATION', 0.0), (u'ACCOLADE', 0.0), (u'ACCOMMODATE', 0.0), (u'ACCOMMODATION', 0.0), (u'ACCOMPANIMENT', 0.0), (u'ACCOMPLISH', 0.0), (u'ACCOMPLISHMENT', 0.0), (u'ACCORDANCE', 0.0), (u'ACCOUNTABLE', 0.0), (u'ACCRUE', 0.0), (u'ACCURACY', 0.0), (u'ACCURATENESS', 0.0), (u'ACHIEVE', 0.0), (u'ACKNOWLEDGEMENT', 0.0), (u'ACQUAINT', 0.0), (u'ACQUAINTANCE', 0.0), (u'ACQUIT', 0.0), (u'ACQUITTAL', 0.0), (u'ADEPT', 0.0), (u'ADEPTNESS', 0.0), (u'ADEQUATE', 0.0), (u'ADHERENCE', 0.0), (u'ADHERENT', 0.0), (u'ADHESION', 0.0), (u'ADHESIVE', 0.0), (u'ADJUNCT', 0.0), (u'ADJUST', 0.0), (u'ADJUSTABLE', 0.0), (u'ADJUSTMENT', 0.0), (u'ADMIRABLE', 0.0), (u'ADMIRATION', 0.0), (u'ADMIRER', 0.0), (u'ADM
# ...

# %%
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.72.42;DATABASE=FB_IMDB;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from Slang  ")

SlangRows = cursor.fetchall()
print SlangRows[0][0],SlangRows[0][3]
# Out:
# 143 1

# %%
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.72.42;DATABASE=FB_IMDB;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from Emotion  ")

EmotionRows = cursor.fetchall()
print EmotionRows[0][2]
# Out:
# :‑)

# %%
tokenizer = RegexpTokenizer(r'\w+')
en_stop = get_stop_words('en') 
lemma = nltk.wordnet.WordNetLemmatizer()
for row in CommentRows:
    
    
    Message= row.Message
    raw = Message.lower()
    
    #計數器
    AdjCount_P=0
    AdjCount_N=0
    EmotionCount_P=0
    EmotionCount_N=0
    SlangCount_P=0
    SlangCount_N=0
    Emotion1=" "
    Slang1=" "
    #切割表情
    Emotokens = raw.split(" ")
    
    for Emotoken in Emotokens:
        
        for emotion in EmotionRows:
            if emotion[2]==Emotoken:
                Emotion1+=emotion[2]
                if emotion[4]==1:
                    EmotionCount_P+=1
                if emotion[4]== -1 :
                    EmotionCount_N+=1

                break
    

    
    tokens = tokenizer.tokenize(raw)
    stopped_tokens = [i for i in tokens if not i in en_stop]
    stemmed_tokens = [lemma.lemmatize(i) for i in stopped_tokens]
    
   
    for token in stemmed_tokens:
        for adj in OpinionRows:
            if(token==adj.Opinion):
                if adj.P_N==0:
                    AdjCount_P+=1
                else :
                    AdjCount_N+=1
                break
        for slang in SlangRows:
            lslang=slang[0].lower()
            if(token==lslang):
                Slang1+=" " +token
                if SlangRows[0][3]==1:
                    SlangCount_P+=1
                if SlangRows[0][3]==-1:
                    SlangCount_N+=1
                break
#     print   AdjCount_P,AdjCount_N,EmotionCount_P,EmotionCount_N,SlangCount_P,SlangCount_N,Emotion1,Slang1,row.PostNO,row.CommentNO
#     UpdateSQL()

# %%
def UpdateSQL():
    command=('UPDATE CommentOpinion SET AdjCount_P = ? ,'
            ' AdjCount_N=? ,EmotionCount_P=?,EmotionCount_N=?,SlangCount_P=?,SlangCount_N=?,Emotion=?,Slang=? '
             'WHERE PostNO = ? and CommentNO=?'
             )

    
    cursor.execute(command,(AdjCount_P,AdjCount_N,EmotionCount_P,EmotionCount_N,SlangCount_P,SlangCount_N,Emotion1,Slang1,row.PostNO,row.CommentNO))
    conn.commit()

# %%
cursor.close()
conn.close()

# %%
print 1
# Out:
# 1

# %%
a='He couldve accomplished so much in his life and career. Such a shame he had to die so tragically, and so young . . . just like his father. May they both continue resting in peace. :('
print a
tokens = a.split(" ")
print tokens
stopped_tokens = [i for i in tokens if not i in en_stop]
print stopped_tokens
stemmed_tokens = [lemma.lemmatize(i) for i in stopped_tokens]
print stemmed_tokens

# %%
jieba.set_dictionary('C:\Users\qoo\dict.txt')
content="我是帥哥"
words = jieba.cut(content, cut_all=False)
for i in words:
    print i
# Out:
# Building prefix dict from C:\Users\qoo\dict.txt ...
# DEBUG:jieba:Building prefix dict from C:\Users\qoo\dict.txt ...
# Loading model from cache c:\users\qoo\appdata\local\temp\jieba.ue6c4b4709909b7110069926ff0ce5220.cache
# DEBUG:jieba:Loading model from cache c:\users\qoo\appdata\local\temp\jieba.ue6c4b4709909b7110069926ff0ce5220.cache
# Loading model cost 0.662 seconds.
# DEBUG:jieba:Loading model cost 0.662 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# 我
# 是
# 帥哥
