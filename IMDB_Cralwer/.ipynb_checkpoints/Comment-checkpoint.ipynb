# %%
import json
import requests
import string
from collections import Counter


ACCESSTOKEN  = 'CAACEdEose0cBAPwUq22GzxrxroWF0lspTP3qwFy4zxSmGB0ZC5udZBLKWIIsKTJ9BxAhfiBZBZCxN5KdDEQfLDRFn1JTSnZADBk5N346VChfUzwrnZCJREU3fuLkGJmstNzg4S3Tz0SbtEZCZBwxJROUHPmtlZALORU3oVoijeziqlN1jOMHXYFuFN5RlXjPgfarTNYdHztvlJUnNTLpAvSkZA'
PostUrl ='https://graph.facebook.com/v2.5/15925638948_10154036664053949/comments?fields=like_count,message,comment_count,from,id&limit=1000&access_token='+ACCESSTOKEN

res = requests.get(PostUrl)

jd = json.loads(res.text)

PostID= jd['data'][0]['id']
#print jd['data'][0]['like_count']
len(jd['data'])
# Out:
# 1000

# %%
import time
import pyodbc
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.72.42;DATABASE=FB_IMDB;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from FBPost where PostNO>4392  order by PostNO asc")

rows = cursor.fetchall()

ACCESSTOKEN  = 'CAACEdEose0cBAPwUq22GzxrxroWF0lspTP3qwFy4zxSmGB0ZC5udZBLKWIIsKTJ9BxAhfiBZBZCxN5KdDEQfLDRFn1JTSnZADBk5N346VChfUzwrnZCJREU3fuLkGJmstNzg4S3Tz0SbtEZCZBwxJROUHPmtlZALORU3oVoijeziqlN1jOMHXYFuFN5RlXjPgfarTNYdHztvlJUnNTLpAvSkZA'
for row in rows :
    
    CommentNO=1
    
    PostUrl ='https://graph.facebook.com/v2.5/{}/comments?fields=like_count,message,comment_count,from,id&limit=1000&access_token='+ACCESSTOKEN
    PostID= row.id
    PostNO= row.PostNO
    #print PostNO
    
    res = requests.get(PostUrl.format(PostID))
    jd = json.loads(res.text)
    print PostNO
    if 'Unsupported get request'in res.text :
        insertSQL2()
        continue
    if 'data' in res.text and  'paging'not in res.text:
        insertSQL2()
        continue
    while 'paging'not in res.text  :
        i=1
        time.sleep(1)
        print PostUrl.format(PostID)
        res = requests.get(PostUrl.format(PostID))
        jd = json.loads(res.text)
        
    while 'next' in jd['paging'] :
        print PostNO,PostID
        for data in jd['data']:
            like_count= data['like_count']
            message=data['message']
            comment_count=data['comment_count']

            Name= data['from']['name']
            UserID= data['from']['id']
            CommentID=data['id']

            insertSQL()
            if(CommentNO%1000==0):
            
                url=jd['paging']['next']
                time.sleep(1)
                res=requests.get(url)
                jd = json.loads(res.text)
            while 'paging' not in res.text:
                i=1
                time.sleep(1)
                print PostUrl.format(PostID)
                res = requests.get(PostUrl.format(PostID))
                jd = json.loads(res.text)  

            CommentNO+=1
        
        
        
    for data in jd['data']:
        like_count= data['like_count']
        message=data['message']
        comment_count=data['comment_count']

        Name= data['from']['name']
        UserID= data['from']['id']
        CommentID=data['id']

        insertSQL()
        if(CommentNO%1000==0):
            
            url=jd['paging']['next']
            
            res=requests.get(url)
            jd = json.loads(res.text)
        CommentNO+=1
# Out:
# 4393
# 4393 15925638948_10152205241788949
# 4393 15925638948_10152205241788949
# 4393 15925638948_10152205241788949
# 4394
# 4395
# 4395 15925638948_10152204746523949
# 4396
# 4397
# 4398
# 4399
# 4400
# 4401
# 4402
# 4403
# 4404
# 4404 15925638948_10152198508378949
# 4405
# 4406
# 4407
# 4408
# 4409
# 4409 15925638948_10152194155133949
# 4410
# 4411
# 4412
# 4413
# 4414
# 4415
# 4416
# 4417
# 4418
# 4419
# 4420
# 4420 15925638948_10152189455343949
# 4421
# 4422
# 4423
# 4424
# 4425
# 4426
# 4427
# 4428
# 4429
# 4430
# 4430 15925638948_10152185504298949
# 4430 15925638948_10152185504298949
# 4431
# 4432
# 4433
# 4434
# 4435
# 4436
# 4437
# 4437 15925638948_10152180674658949
# 4438
# 4439
# 4440
# 4441
# 4442
# 4443
# 4444
# 4445
# 4446
# 4447
# 4448
# 4449
# 4449 15925638948_10152172970438949
# 4449 15925638948_10152172970438949
# 4450
# 4451
# 4452
# 4453
# 4454
# 4455
# 4456
# 4457
# 4457 15925638948_10152164427268949
# 4457 15925638948_10152164427268949
# ...

# %%
def insertSQL():
    command="INSERT INTO FBComment (PostNO,CommentNO,Name,Message,CommentID,UserID,LikeCount,ReplyCount) VALUES (?,?,?,?,?,?,?,?)"

    cursor.execute(command,(PostNO,CommentNO,Name,message,CommentID,UserID,like_count,comment_count))
    conn.commit()

# rows = cursor.fetchall()
# for row in rows:
#     print row.id

# %%
def insertSQL2():
    command="INSERT INTO FBComment (PostNO) VALUES (?)"

    cursor.execute(command,(PostNO))
    conn.commit()

# %%
def EveryData(jd):
     for data in jd['data']:
        like_count= data['like_count']
        message=data['message']
        comment_count=data['comment_count']
        
        Name= data['from']['name']
        UserID= data['from']['id']
        CommentID=data['id']
        global CommentNO
        insertSQL(PostNO,CommentNO,Name,message,CommentID,UserID,like_count,comment_count)
        if(CommentNO%200==0):
            
                url=jd['paging']['next']
                time.sleep(0.1)
                res=requests.get(url)
                jd = json.loads(res.text)
                

        CommentNO+=1

# %%
cursor.close()
conn.close()

# %%
 res = requests.get('https://graph.facebook.com/v2.5/{}/comments?fields=like_count,message,comment_count,from,id&limit=200&access_token=')
#print res.text
if 'error'in res.text:
    print 'error'
# Out:
# error
