# %%
import json
import requests
import string
from collections import Counter


ACCESSTOKEN  = 'CAACEdEose0cBADwoAEEYieaRMtIKaTr25EKEcfee42bOYkPq9wpBpGYnojvTpZAUziZBZBMSSk5uosXoVqdIPOMFDB2R1s3lhcEUQWmCQlwjw7sAkJwjZA9ZBSHGzpNZA4ceXNQesmogoDxzcxTqKibzhaHLApwP6m8hOkTLC0ZAjYV0ixRSl4QJkiP5IyG6KHY6bLZBboPybkPiEOnEm8AP'
PostUrl ='https://graph.facebook.com/v2.5/15925638948_10154212321798949/likes?pretty=0&limit=1000&access_token='+ACCESSTOKEN

res = requests.get(PostUrl)

jd = json.loads(res.text)

#PostID= jd['data'][0]['id']
print res.text
#len(jd['data'])
# Out:
# {"error":{"message":"Error validating access token: Session has expired on Monday, 04-Apr-16 13:00:00 PDT. The current time is Monday, 04-Apr-16 23:19:03 PDT.","type":"OAuthException","code":190,"error_subcode":463,"fbtrace_id":"HGUCgdrnm+O"}}

# %%
import time
import pyodbc
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.72.42;DATABASE=FB_IMDB;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from FBPost where PostNO>6192 order by PostNO asc")

rows = cursor.fetchall()

ACCESSTOKEN  = 'CAACEdEose0cBACR53oy43ZBorghvaVdmwjFmINW4eKMvCinNABxyfndNJvh5I06TuHiANJIAmVrW06h6cZCcNQBYFF457f74Mctq7wrnTrVnFM5HkAtRTzQtAkkvdjdQkm0A3wDe4UDpVGxmxKHi0wMQz5PsluU9uaDIZA9FSszSCiUrxzmwtphmF9nwUYH2gMZB0D9ZCE3aK0ftuQ5cF'
for row in rows :
    LikeNO=1
    PostUrl ='https://graph.facebook.com/v2.5/{}/likes?pretty=0&limit=1000&access_token='+ACCESSTOKEN
    PostID= row.id
    PostNO= row.PostNO
    #print PostNO
    #time.sleep(0.1)
    res = requests.get(PostUrl.format(PostID))
    jd = json.loads(res.text)
    
    print PostNO
    
    if 'Unsupported get request'in res.text :
        insertSQL2()
        continue
    if 'data' in res.text and  'paging'not in res.text:
        insertSQL2()
        continue
    while 'paging'not in res.text  :
        i=1
        time.sleep(1)
        print PostUrl.format(PostID)
        res = requests.get(PostUrl.format(PostID))
        jd = json.loads(res.text)
    while 'next' in jd['paging']:
        for data in jd['data']:
            name= data['name']
            id= data['id']
            insertSQL()
            if(LikeNO%1000==0):
                url=jd['paging']['next']
                #time.sleep(0.1)
                res=requests.get(url)
                jd = json.loads(res.text)
            LikeNO+=1
            while 'paging' not in res.text:
                i=1
                time.sleep(1)
                print PostUrl.format(PostID)
                res = requests.get(PostUrl.format(PostID))
                jd = json.loads(res.text)  
        
    for data in jd['data']:
        name= data['name']
        id= data['id']
        insertSQL()
        LikeNO+=1
# Out:
# 6193
# 6194
# 6195
# 6196
# 6197
# 6198
# 6199
# 6200
# 6201
# 6202
# 6203
# 6204
# 6205
# 6206
# 6207
# 6208
# 6209
# 6210
# 6211
# 6212
# 6213
# 6214
# 6215
# 6216
# 6217
# 6218
# 6219
# 6220
# 6221
# 6222
# 6223
# 6224
# 6225
# 6226
# 6227
# 6228
# 6229
# 6230
# 6231
# 6232
# 6233
# 6234
# 6235
# 6236
# 6237
# 6238
# 6239
# 6240
# 6241
# 6242
# 6243
# 6244
# 6245
# 6246
# 6247
# 6248
# 6249
# 6250
# 6251
# 6252
# 6253
# 6254
# 6255
# 6256
# 6257
# 6258
# 6259
# 6260
# 6261
# 6262
# 6263
# 6264
# 6265
# 6266
# 6267
# 6268
# 6269
# 6270
# 6271
# 6272
# 6273
# 6274
# 6275
# 6276
# 6277
# 6278
# 6279
# 6280
# 6281
# 6282
# 6283
# 6284
# 6285
# 6286
# 6287
# 6288
# 6289
# 6290
# 6291
# 6292
# 6293
# 6294
# 6295
# 6296
# 6297
# 6298
# 6299
# 6300
# 6301
# 6302
# 6303
# 6304
# 6305
# 6306
# 6307
# 6308
# 6309
# 6310
# 6311
# 6312
# 6313
# 6314
# 6315
# 6316
# 6317
# 6318
# 6319
# 6320
# 6321
# 6322
# 6323
# 6324
# 6325
# 6326
# 6327
# 6328
# 6329
# 6330
# 6331
# 6332
# 6333
# 6334
# ...

# %%
def insertSQL():
    command="INSERT INTO FBPostLike (PostNO,LikeNO,UserID,UserName) VALUES (?,?,?,?)"

    cursor.execute(command,(PostNO,LikeNO,id,name))
    conn.commit()

# rows = cursor.fetchall()
# for row in rows:
#     print row.id

# %%
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c7e40653ca6f> in <module>()
# ----> 1 cursor.close()
#       2 conn.close()
#
# NameError: name 'cursor' is not defined

# %%
def insertSQL2():
    command="INSERT INTO FBComment (PostNO) VALUES (?)"

    cursor.execute(command,(PostNO))
    conn.commit()
