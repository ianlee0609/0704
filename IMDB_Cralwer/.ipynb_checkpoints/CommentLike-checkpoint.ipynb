# %%
import json
import requests
import string
from collections import Counter


ACCESSTOKEN  = 'CAACEdEose0cBACFnIZB6ghN9WwZB6NDaf3MCkrHeqXvftlXkcz0uTgZBPxYFSy2avK7ZCAb0FW9MlyxSVcZBfluVPBfxvfUHFAfAfuMuel7ez7HEizw4a6LgC4QMKnNjnhDcO0ORwkoSU7YZAt4avPlTrdyiXJIq9j7iW9pI1GdJ9HN3AkPPOsGF7vk0c7dfA3VwZBZCTIl46m9DWLZAq9Obf'
PostUrl ='https://graph.facebook.com/v2.5/10154049289398949_10154049291803949/likes?limit=1000&access_token='+ACCESSTOKEN

res = requests.get(PostUrl)
print res.text
jd = json.loads(res.text)

PostID= jd['data'][0]['id']
#print jd['data'][0]['like_count']
len(jd['data'])
# Out:
# {"data":[{"id":"10152096367460875","name":"Kaelin O'Reilly"},{"id":"10203613687840819","name":"Nico Sicaa"},{"id":"10152427786161182","name":"Joanna Parlak"},{"id":"672893892803143","name":"Matthew Khalili"},{"id":"150435358631027","name":"Reese Dayna Gardner"},{"id":"870942149599022","name":"Myles Dotzler"},{"id":"644126212373269","name":"Sam Gianfala"},{"id":"613256878784494","name":"Dylan Bai"},{"id":"10203313294090296","name":"Karen Elvidge"},{"id":"670595412987872","name":"Julia Bint"},{"id":"878916968805233","name":"Joe Cruickshank"},{"id":"10152559853783720","name":"Raluca Victoria"},{"id":"10205249965551701","name":"Phil Ondusko"},{"id":"652061204864173","name":"Elena Caraman"},{"id":"10152439905076135","name":"Mariann St\u00f8le"},{"id":"836707036368525","name":"Rico Hack"},{"id":"10200880453933537","name":"Shawn Roche"},{"id":"753725797994443","name":"Tika Sari"},{"id":"10202952060656112","name":"Tiger Lilly"},{"id":"144926995887423","name":"Karolis Klimas"},{"id":"10152189047192251","name":"Chris 'Birks' Birkett"},{"id":"545961858874478","name":"Jacob Ferrell"},{"id":"10202881317381482","name":"Lora Al Mandalawi"},{"id":"918038831558773","name":"H\u0103lm\u0103gean \u0218erban"},{"id":"1438078773102349","name":"Sovran Hoti"},{"id":"10154804300485089","name":"Katie Hemming"},{"id":"546634855457783","name":"Dexter Jettster"},{"id":"687132271403574","name":"Julie Crumpton"},{"id":"10203786632459396","name":"Tom Polite"},{"id":"986049684742388","name":"Donna Zubres Ligi"},{"id":"1437721533214668","name":"Merike K\u00e4ver"},{"id":"10203810642440287","name":"Antoine Delisle"},{"id":"10152327521757394","name":"Geison Benevides"},{"id":"10152511432507214","name":"Jeremy Wollersheim"},{"id":"10153396077176040","name":"Arturo Garay"},{"id":"776584772384025","name":"Eva Du"},{"id":"741348585927398","name":"Justin Richards"},{"id":"10152698130971323","name":"Emily Coates"},{"id":"10203731054738414","name":"Andrea Athos"},{"id":"10205068170294393","name":"Emil Bille"},{"id":"806080829411536","name":"Jen Vasbinder"},{"id":"535681636550482","name":"Ana Milojevi\u0107"},{"id":"10152470302783829","name":"Jassmin Elliot Jones"},{"id":"675261605854656","name":"Ana Maria"},{"id":"668859516512879","name":"Jimmy Edwards"},{"id":"1555101708037646","name":"Samuel Smith"},{"id":"859560017454359","name":"Jay Jay"},{"id":"808703372519148","name":"Hayley Chan"},{"id":"664417973594260","name":"Jonah Hewetson"},{"id":"466930636774831","name":"Sharon Saunders Martin"},{"id":"914577968570668","name":"Thadoe Wai"},{"id":"10152412895961587","name":"Elvis Joze"},{"id":"10152282358356746","name":"Justin Mcmillan"},{"id":"693810384032715","name":"Rachel Webb"},{"id":"1041850052508976","name":"Kevin Serrazine"},{"id":"10203907084544491","name":"Andreas Themistokleous"},{"id":"10152660544213969","name":"Connor Ryan"},{"id":"10203829520477834","name":"Vice Matu\u0161an"},{"id":"959862017371733","name":"Raymond Cavendish"},{"id":"10152278800180292","name":"Wilmer Alvarez"},{"id":"1470902593126936","name":"Chris Lees"},{"id":"757840544310716","name":"Pranesh Kumar"},{"id":"10201415643184543","name":"\u017dan Furman"},{"id":"764844550193414","name":"Elliott Ames"},{"id":"588912151226345","name":"Alaa Hlal"},{"id":"672415636175900","name":"Michelle Bornand Diaz"},{"id":"10102350410106249","name":"Jeri Hyde"},{"id":"10204191518205754","name":"Hannah Pederson"},{"id":"772848986061639","name":"Chelsea Simpson"},{"id":"10152299451237900","name":"Alina Ciocarlie"},{"id":"1630625440501711","name":"Christopher Layug"},{"id":"373316396158609","name":"Frankie Peterson"},{"id":"10152000321601960","name":"Jessica Liczbinski"},{"id":"701546833263984","name":"Joakim Sandberg"},{"id":"858474447500469","name":"Rui Santos"},{"id":"787493871296205","name":"Rita Escudeiro"},{"id":"10154017993440158","name":"Samantha Fay Gadsby"},{"id":"786358131421094","name":"Andy Waters"},{"id":"853495744702577","name":"Gustavo Silva"},{"id":"10203981182119492","name":"Anthony Le"},{"id":"1 ...
# 700

# %%
import time
import pyodbc
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.72.42;DATABASE=FB_IMDB;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from [FBComment] where PostNO>0 and ReplyCount>0  order by PostNO,CommentNO asc")

rows = cursor.fetchall()


ACCESSTOKEN  = 'CAACEdEose0cBACR53oy43ZBorghvaVdmwjFmINW4eKMvCinNABxyfndNJvh5I06TuHiANJIAmVrW06h6cZCcNQBYFF457f74Mctq7wrnTrVnFM5HkAtRTzQtAkkvdjdQkm0A3wDe4UDpVGxmxKHi0wMQz5PsluU9uaDIZA9FSszSCiUrxzmwtphmF9nwUYH2gMZB0D9ZCE3aK0ftuQ5cF'
for row in rows :
    LikeNO=1
    PostUrl ='https://graph.facebook.com/v2.5/{}/likes?pretty=0&limit=1000&access_token='+ACCESSTOKEN
    CommentID= row.CommentID
    CommentNO= row.CommentNO
    
    res = requests.get(PostUrl.format(CommentID))
    jd = json.loads(res.text)
    
   
    
    if 'Unsupported get request'in res.text :
        insertSQL2()
        continue
    if 'data' in res.text and  'paging'not in res.text:
        insertSQL2()
        continue
    while 'paging'not in res.text  :
        i=1
        time.sleep(1)
        print PostUrl.format(PostID)
        res = requests.get(PostUrl.format(PostID))
        jd = json.loads(res.text)
    while 'next' in jd['paging']:
        for data in jd['data']:
            name= data['name']
            id= data['id']
            insertSQL()
            if(LikeNO%1000==0):
                url=jd['paging']['next']
                #time.sleep(0.1)
                res=requests.get(url)
                jd = json.loads(res.text)
            LikeNO+=1
            while 'paging' not in res.text:
                i=1
                time.sleep(1)
                print PostUrl.format(PostID)
                res = requests.get(PostUrl.format(PostID))
                jd = json.loads(res.text)  
        
    for data in jd['data']:
        name= data['name']
        id= data['id']
        insertSQL()
        LikeNO+=1
# Out:
# (1, 1, u'Peggy Peg PLk', u'For starters:He is papa Winchester :P', u'10154212321798949_10154212325023949', u'607043606082377', 196, 19)
# 10154212321798949_10154212325023949 1

# %%
def insertSQL():
    command="INSERT INTO FBReply (PostNO,CommentNO,ReplyNO,ReplyID,Name,Message,UserID,LikeCount) VALUES (?,?,?,?,?,?,?,?)"

    cursor.execute(command,(PostNO,CommentNO,ReplyNO,ReplyID,Name,message,UserID,like_count))
    conn.commit()

# rows = cursor.fetchall()
# for row in rows:
#     print row.id

# %%
def insertSQL2():
    command="INSERT INTO FBComment (PostNO) VALUES (?)"

    cursor.execute(command,(PostNO))
    conn.commit()
