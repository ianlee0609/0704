# %%
import requests

res =requests.get('http://www.appledaily.com.tw/realtimenews/section/new/')
print res.text
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="zh-TW" class="ie6 ielt8"> <![endif]-->
# <!--[if IE 7 ]>    <html lang="zh-TW" class="ie7 ielt8"> <![endif]-->
# <!--[if IE 8 ]>    <html lang="zh-TW" class="ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--> <html lang="zh-TW"> <!--<![endif]-->
# <head>
#   <meta charset="utf-8" />
#   <title>蘋果即時新聞｜蘋果日報｜Apple Daily</title>
#   <meta name="description" content="蘋果日報網站提供即時、快速、豐富的最新時事動態，包含國際、社會、娛樂、政治、生活、財經等最新訊息，並為您搜奇地球村萬象與趣聞，強調有圖有真相、影片最明白，讓您時時刻刻掌握天下事！" />
#   <meta name="keywords" content="蘋果日報,Apple Daily,台灣,壹傳媒,Apple, Animation news, Action News, Apple news, news,蘋果,即時,最新,蘋果新聞,新聞,壹週刊,壹電視,動新聞,即時新聞,Facebook,臉書,蘋果粉絲團,plurk,twitter,留言,分享,按讚,天氣,影音新聞,影片,影音,行動版,手機,App,Android,iphone,Mango,爆料,投稿,發票,統一發票,RSS,生活,國際,娛樂,體育,副刊,財經,股市,樂透,威力彩,社會,熱門,彩券,頭彩" />
#   <meta property="og:title" content="蘋果即時新聞｜蘋果日報｜Apple Daily"/>
#   <meta property="og:image" content="http://twimg.edgesuite.net/appledaily/images/core/logo_bg.png"/>
# ...

# %%
from bs4 import BeautifulSoup as bs

for page in range(1,4):
    res =requests.get('http://www.appledaily.com.tw/realtimenews/section/new/{}'.format(page))
    soup=bs(res.text)

    for ele in soup.select('.rtddd .rtddt'):
        print ele.select('time')[0].text,ele.select('h2')[0].text, ele.select('h1')[0].text
# Out:
# 14:57 體育 ​【有片】柯瑞傷後復出拿40分　勇士擊敗...(24311)
# 14:57 財經 【有片】全家推高價茶新品　今年自有品牌營...(207)
# 14:55 娛樂 南拳媽媽等6年發片　周董虧「把彈頭換掉」(0)
# 14:55 特企
#
# 【特企】以綸現場爆怒 Teddy找打手團 (1936)
#
#
# 14:53 社會 酒駕遇警主動自首　誠實男獲緩起訴(44)
# 14:52 社會 反恐維安　起獲貨櫃輪走私百萬香菇(36)
# 14:51 娛樂 如花慧慈合體湯尼陳　酸法拉利姊太貴(120)
# 14:51 壹週刊 【壹週刊】端午連假疏運　台灣高鐵加開12...(17)
# 14:50 社會 hTC前總經理　買地被騙1.2億(119)
# 14:48 地產 【買房問蘋果】1樓嫌吵　要求送羊奶用走的...(6850)
# 14:48 財經 上緯風電子公司　獲25億元聯貸(104)
# 14:47 社會 12人都戶籍都在他服務處　里長勝選遭起訴(180)
# 14:45 娛樂 【有片】阿美套現3億貼前夫　40億土地飛...(108)
# 14:45 壹週刊 【壹週刊】你坐過嗎？10條迷死人的日本鐵...(37)
# 14:45 國際 【央廣RTI】中國良心犯郭飛雄受虐 國際...(2)
# 14:44 社會 路邊停車真難！　這位警察就是停不進去(1254)
# 14:44 政治 郭美珠批評無能花瓶　洪慈庸：「美珠姊姊」...(1534)
# 14:43 生活 【有片】外國女孩看台灣慣用的４２公分　直...(23997)
# 14:43 壹週刊 【壹週刊】李騰光榮回台　感謝徐乃麟黃子佼(339)
# 14:43 財經 涉9大缺失　新壽遭金管會罰120萬元(74)
# 14:43 論壇 【民報王輝生專文】馬英九上台初及下台前的...(80)
# 14:41 國際 【有片】慶金正恩當選黨魁　數十萬人紙花祝...(1296)
# 14:41 生活 【有片】柯P：中國施壓WHA　如周子瑜事...(1631)
# 14:41 國際 納粹奪名家畫作　法政府物歸原主(120)
# 14:41 生活 下月起　機車路考新增4項考驗項目(128)
# 14:39 社會 【有片】男拿鋸子亂揮舞　嚇壞懷胎9月孕婦(3622)
# ...

# %%
res =requests.get('https://www.ptt.cc/bbs/Food/index5400.html')
print res.text
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Food 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-print.css" media="print">
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.17/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
#   _gaq.push(['_trackPageview']);
#
# ...

# %%
soup=bs(res.text)
for ele in soup.select('.r-ent'):
    print ele.select('.title')[0].text,ele.select('.date')[0].text,ele.select('.author')[0].text
# Out:
# [請益] 台北排餐請益
#  5/10 xz35s8pq
#
# [食記] 彰化 員林 指月亭 刀工精湛 味實不豔
#  5/10 Sherlock56
#
# [食記] 桃園市。百花窯鍋品  怕辣也愛的養生火鍋
#  5/10 kusuriyatera
#
# [食記] 台北 慶城海南雞飯
#  5/10 NouTsan
#
# [食記] 加賀洋風拉麵食堂 台北市 捷運東湖站
#  5/10 m7i7n7g7
#
# [食記] 台北東區-新加坡文東記直營之文慶雞
#  5/10 elittle
#
# [食記] 台北松菸 黑米*墨魚燉飯黑到發亮
#  5/10 grace05026
#
#
# 				(本文已被刪除) [h19880628]
#
# 			 5/10 -
#
# [廣宣] 台北中山北路照島時計店
#  5/10 h19880628
#
# [請益]  單點式燒肉選擇～
#  5/10 ynin1220
#
# [食記] 宜隆便當 舊草嶺隧道 一日遊 鐵馬隧道
#  5/10 cocoluluup
#
# [食記]新北市 八里 芭達桑 原住民人文主題餐廳
#  5/10 lasor
#
# [食記][高雄市] 本家台灣咖哩
#  5/10 JeremyKSKGA
#
# [食記]【京都】京都 伏見稻荷470年現烤鰻魚丼飯
#  5/10 vanilladiary
#
# [請益] 生日鐵板燒
#  5/10 moonns
#
# [食記] 竹北。黑瓦鬆餅
#  5/10 novitw
#
# [食記] [台中] 泰后月亮蝦餅，泰式涼拌泡麵清爽
#  5/10 buuzkuo
#
# [食記]台北信義區 PUTIEN 莆田 新加坡最佳亞洲餐廳
#  5/10 kuoyuri
#
# [食記] 新竹 老爺酒店 假日壽喜燒吃到飽
#  5/10 supergodking
#
# [食記] 台北北投 莎諾歐法西餐
#  5/10 pancher7

# %%
import jieba
from collections import Counter
dic=Counter()
soup=bs(res.text)

for page in range(5390,5400):
    res =requests.get('https://www.ptt.cc/bbs/Food/index{}.html'.format(page))
    soup=bs(res.text)
    for ele in soup.select('.r-ent'):
        for cut in jieba.cut(ele.select('.title')[0].text):
            dic[cut]+=1
for word in dic.most_common(100):
    if(len(word[0])>=2):
        print word[0],word[1]
# Out:
# 食記 178
# 台北 55
# 台南 14
# 餐廳 12
# 新竹 12
# 廣宣 11
# 大安 10
# 高雄 10
# 日本 9
# 台北市 8
# 新北 8
# Fw 8
# 東區 7
# 料理 7
# 牛肉 7
# 好吃 7
# 咖啡 7
# 午餐 6
# 永和 6
# 日式 6
# 京都 5
# Cafe 5
# 夜市 5
# 中山 4
# 燒肉 4
# 市場 4
# 大阪 4
# 韓國 4
# 專賣店 4
# 中西 4
# 新北市 4
# 創意 3
# 車站 3
# HOME 3
# 請益 3
# 澳門 3
# 桃園 3
# 美味 3
# 新店 3
# 世界 3
# 板橋 3
# 牛奶 3

# %%
import jieba

word=jieba.cut("今天天氣很好")
for ele in word:
    print ele
# Out:
# 今天
# 天氣
# 很
# 好

# %%
dic=Counter()
dic={'dog':5,'cat':56}
print dic.keys()
print dic.values()
print dic['dog']
# Out:
# ['dog', 'cat']
# [5, 56]
# 5

# %%
import requests
import jieba
from collections import Counter
from bs4 import BeautifulSoup as bs

dic=Counter()
for page in range(1,5):

    res=requests.get('http://www.appledaily.com.tw/realtimenews/section/new/{}'.format(page))
    soup=bs(res.text)
    for ele in soup.select('.rtddt'):
        title=  ele.select('a')[0]['href'].split('/')[-1]
        for cut in  jieba.cut(title):
            dic[cut]+=1
for word in dic.most_common(100):
    if(len(word[0])>=2):
        print word[0],word[1]
# Out:
# 有片 24
# 週刊 6
# RFI 6
# 百里 6
# 法廣 6
# 更新 5
# 總統 5
# 台灣 5
# GAME 4
# RTI 4
# 央廣 4
# 民報 4
# 停車 3
# 30 3
# 就是 3
# 大學 3
# 議員 3
# 12 3
# 今年 3
# 警察 3
# 海洋 2
# 宏碁 2
# 地價 2
# 李克強 2
# 權威 2
# 520 2
# 專欄 2
# 影片 2
# 未來 2
# 女生 2
# 肉體 2
# 原因 2
# 這樣 2
# 花蓮 2
# 霸氣 2
# 政策 2

# %%
import jieba
from collections import Counter

# %%
import requests
from bs4 import BeautifulSoup as bs

for page in range(1,6):
    res=requests.get('http://www.appledaily.com.tw/realtimenews/section/new/'+str(page))
    soup=bs(res.text)
    for ele in soup.select('.rtddt'):
        print ele.select('h1')[0].text
# Out:
# 12人戶籍都在他服務處　里長勝選遭起訴(2163)
# 今晚11縣市大雨特報　注意短時強降雨(0)
# 【有片】鄭捷520前槍決？　律師：恐不及...(137992)
#
#
# 【特企】以綸現場爆怒 Teddy找打手團 (2306)
#
#
# 廖文揚重返先發輪值　最愛請教西口文也(0)
# 【壹週刊】太厲害想逼死誰　梅姨開金口導演...(0)
# 瑞軒淡季不淡　4月營收16.9億元(0)
# 中研院院長選舉的基本事實(0)
# 【GAME啥】「魔獸」拍電影　仔細看竟是...(48)
# 【血跡斑斑】高喊「真主至大」　德狂男揮刀...(10381)
# 林志賢兼練游擊　希望備而不用(225)
# 赴中國工作遇爆炸　男獲賠千萬(210)
# 酒駕逃逸增加刑責有實務困難(26)
# 【台灣英文新聞】比利時發行2016里約奧...(0)
# 和碩Q2是谷底　上半年無好消息(0)
# 【有片】警車被噴漆塗鴉　我有話說...(527)
# Q1大衰退　上緯董座：自己也背了黑鍋(360)
# 【更新】賈靜雯操刀剃頭　咘咘老爸入伍倒數(4837)
# 大巨蛋再添鄰損　議員爆刑事局也地層下陷(315)
# 靠北假貴婦　吃龍蝦鮑魚卻為幫傭點差別餐(2428)
# 【有片】跑壘美技　頭盔自己會找主人(160)
# 【有片】就是他！　讓雪神嘆「人都會看走眼...(2668)
# 【壹週刊】南拳媽媽第四代　周杰倫挖苦彈頭(190)
# 太誇張  無照停車場當路霸佔路拐人停車 ...(450)
# 男女陳屍茄萣海邊　死因身份待查(932)
# 台南芒果遇50年慘況　救助申請至16日(563)
# 藏孕肚高手！花邊教主披BURBERRY超...(648)
# 4歲童走失　6歲童帶他報案(871)
# 【獨家】菲律賓新總統長期友台　今年初曾密...(1015)
# 情侶吵架霸氣拉女友上車　警察救援搜出毒(1122)
# 【中職先發戰報】統一獅隊對戰義大犀牛(245)
# 開始下雨了！鄭明典：下班回家路上小心(1308)
# 【民報專欄】三個傻瓜救回500棵罕病桂花...(501)
# 【央廣RTI】機車情境筆考上路 「5大殺...(268)
# 宏碁員工暗槓電腦轉賣　下場是這樣(2385)
# 威航日本回台班機故障　旅客跳腳(914)
# 犀牛主場迎戰統一　羅力vs.吉爾(368)
# ...

# %%
from bs4 import BeautifulSoup as bs
html_sample=' \
<html> \
<body> \
<h1 id="title">Hello World</h1> \
<a href="#" class="link">This is link1</a> \
<a href="# link2" class="link">This is link2</a> \
</body> \
</html>'
soup=bs(html_sample)
print soup.select('.link')
# Out:
# [<a class="link" href="#">This is link1</a>, <a class="link" href="# link2">This is link2</a>]
