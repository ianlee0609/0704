# %%
array=['a','b','c','d']

items = ['a','e' ,'c', 'd','b']
k=0
# aindex= items.index('a')
# bindex=items.index('c')
# items=items[aindex+1:bindex]
head='a'
tail='b'
headIndex=items.index(head)
tailIndex=items.index(tail)
items=items[headIndex+1:tailIndex]
# items.remove(head)
# items.remove(tail)
print items
from itertools import permutations
for i in range(2,len(items)+1):
    for p in permutations(items,i):
        k+=1
        text=""
        for n in p:
           
            text+=n
        number=str(i-1)    
        print number+','+ head+text+tail
# Out:
# ['e', 'c', 'd']
# 1,aecb
# 1,aedb
# 1,aceb
# 1,acdb
# 1,adeb
# 1,adcb
# 2,aecdb
# 2,aedcb
# 2,acedb
# 2,acdeb
# 2,adecb
# 2,adceb

# %%
graph = {'A': ['B', 'C'],
             'B': ['C', 'D'],
             'C': ['D'],
             'D': ['C'],
             'E': ['F'],
             'F': ['C']}
print find_path(graph, 'A', 'D')

print find_all_paths(graph, 'A', 'D')
# Out:
# ['A', 'B', 'C', 'D']
# [['A', 'B', 'C', 'D'], ['A', 'B', 'D'], ['A', 'C', 'D']]

# %%
 def find_path(graph, start, end, path=[]):
        path = path + [start]
        if start == end:
            return path
        if not graph.has_key(start):
            return None
        for node in graph[start]:
            if node not in path:
                newpath = find_path(graph, node, end, path)
                if newpath: return newpath
        return None

# %%
 def find_all_paths(graph, start, end, path=[]):
        path = path + [start]
        if start == end:
            return [path]
        if not graph.has_key(start):
            return []
        paths = []
        for node in graph[start]:
            if node not in path:
                newpaths = find_all_paths(graph, node, end, path)
                for newpath in newpaths:
                    paths.append(newpath)
        return paths

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-14e2f149ff8c> in <module>()
#       1 a={}
# ----> 2 print a[0]
#
# KeyError: 0

# %%
a={}
a['b']=['c','d']
a['c']=['e','b']
a['b'].append('e')

print find_all_paths(a,'b','e')
# Out:
# [['b', 'c', 'e'], ['b', 'e']]

# %%
readTxtLines = open('C:\Users\qoo\FB_User.txt','r').readlines()
print readTxtLines[1]
# Out:
# U38	U8

# %%
import csv
f = open('C:\Users\qoo\FB_User.csv', 'r')
Array={}
Array['U8']=['U36']
print Array['U8']
for row in csv.reader(f):
    a=row[1]
   
    
    if not a in Array:
        Array[a] = [row[0]]
    else:
        Array[a].append(row[0])
f.close()
# Out:
# ['U36']
# ['U36', 'U38', 'U48', 'U86', 'U82', 'U88', 'U90', 'U94', 'U105', 'U110', 'U119', 'U139', 'U159', 'U171', 'U186', 'U179', 'U190', 'U246', 'U249', 'U264', 'U263', 'U306', 'U320', 'U338', 'U350', 'U362', 'U377', 'U383', 'U400', 'U414', 'U426', 'U462', 'U464', 'U473', 'U469', 'U475', 'U477', 'U422', 'U481', 'U495', 'U512', 'U532', 'U488', 'U556', 'U564', 'U568', 'U583', 'U589', 'U617', 'U634', 'U636', 'U653', 'U678', 'U717', 'U688', 'U721', 'U734', 'U728', 'U646', 'U738', 'U742', 'U747', 'U751', 'U752', 'U764', 'U772', 'U774', 'U811', 'U815', 'U768', 'U808', 'U816', 'U818', 'U821', 'U831', 'U834', 'U837', 'U840', 'U843', 'U848', 'U855', 'U857', 'U869', 'U871', 'U904', 'U911', 'U822', 'U917', 'U920', 'U935', 'U944', 'U947', 'U952', 'U954', 'U972', 'U975', 'U986', 'U988', 'U955', 'U974', 'U1008', 'U1041', 'U1045', 'U1071', 'U1086', 'U1090', 'U1098', 'U1099', 'U1105', 'U1141', 'U1163', 'U1171', 'U1219', 'U1224', 'U1233', 'U1249', 'U1253', 'U1288', 'U1322', 'U1339', 'U1334', 'U1372', 'U1385', 'U1388', 'U1391', 'U1077', 'U1401', 'U1413', 'U1417', 'U1433', 'U1436', 'U1441', 'U1429', 'U1498', 'U1520', 'U1557', 'U1574', 'U1584', 'U1576', 'U1611', 'U1620', 'U1645', 'U1650', 'U1665', 'U1675', 'U1695', 'U1701', 'U1704', 'U1743', 'U1712', 'U1749', 'U1756', 'U1764', 'U1784', 'U1810', 'U1814', 'U1848', 'U1850', 'U1864', 'U1907', 'U1920', 'U1910', 'U1929', 'U1931', 'U1932', 'U1947', 'U1994', 'U1995', 'U1996', 'U1997', 'U2004', 'U2010', 'U2023', 'U1992', 'U2037', 'U2038', 'U2062', 'U2072', 'U2099', 'U2108', 'U2115', 'U2117', 'U2118', 'U2149', 'U2119', 'U2133', 'U2156', 'U2158']

# %%
print find_path(Array,'U86','U88')
# Out:
# ['U86', 'U2112', 'U186', 'U2115', 'U2119', 'U179', 'U38', 'U48', 'U2110', 'U2153', 'U2163', 'U190', 'U26', 'U2149', 'U171', 'U2118', 'U2133', 'U2117', 'U160', 'U33', 'U49', 'U37', 'U2158', 'U2156', 'U159', 'U2108', 'U139', 'U2099', 'U2026', 'U119', 'U2094', 'U153', 'U82', 'U2059', 'U2020', 'U127', 'U2092', 'U2038', 'U110', 'U2062', 'U130', 'U45', 'U121', 'U101', 'U2066', 'U2072', 'U105', 'U8', 'U88']

# %%
f = open('D:\A.txt', 'w')    # 也可使用指定路徑等方式，如： C:\A.txt
f.write(str(find_all_paths(Array,'U86','U88')))

f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-14374a5c83bc> in <module>()
#       1 f = open('D:\A.txt', 'w')    # 也可使用指定路徑等方式，如： C:\A.txt
# ----> 2 f.write(str(find_all_paths(Array,'U86','U88')))
#       3
#       4 f.close()
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
# ...
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
#       8        for node in graph[start]:
#       9            if node not in path:
# ---> 10                newpaths = find_all_paths(graph, node, end, path)
#      11                for newpath in newpaths:
#      12                    paths.append(newpath)
#
# <ipython-input-60-077b9599732c> in find_all_paths(graph, start, end, path)
# ----> 1 def find_all_paths(graph, start, end, path=[]):
#       2        path = path + [start]
#       3        if start == end:
#       4            return [path]
#       5        if not graph.has_key(start):
#
# KeyboardInterrupt:
