# %%
#FBPost搜尋
import pyodbc
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.68.48;DATABASE=FB_IMDB;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from FBPost  where  [message] like '%trailer%'  ")
rows = cursor.fetchall()
PostNO=rows[-2][0]
Like=rows[-2][3]
Coment=rows[-2][4]
print len(rows)
# Out:
# 1120

# %%
#BoxOffice搜尋
import pyodbc
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.68.48;DATABASE=FB_IMDB;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from [BoxOffice]    ")
BoxOfficerows = cursor.fetchall()

print BoxOfficerows
# Out:
# [(2015, 1, u'Star Wars: The Force Awakens', 936662225, u'J.J. Abrams', u'J.J. Abrams,Michael Arndt,Lawrence Kasdan', u"Lupita Nyong'o,John Boyega,Daisy Ridley,Andy Serkis,Harrison Ford,Carrie Fisher,Mark Hamill,Anthony Daniels,Peter Mayhew"), (2015, 2, u'Jurassic World', 652270625, u'Colin Trevorrow', u'Derek Connolly,Rick Jaffa,Amanda Silver,Colin Trevorrow', u'Chris Pratt,Bryce Dallas Howard,Jake Johnson,Irrfan Khan'), (2015, 3, u'Avengers: Age of Ultron', 459005868, u'Joss Whedon', u'Joss Whedon', u'Robert Downey, Jr.,Chris Hemsworth,Mark Ruffalo,Chris Evans,Scarlett Johansson,Jeremy Renner,Don Cheadle,Aaron Johnson,Paul Bettany,Anthony Mackie,Idris Elba,Stellan Skarsgard,Samuel L. Jackson,Josh Brolin,Andy Serkis*'), (2015, 4, u'Inside Out', 356461711, u'Pete Docter', u'Josh Cooley,Pete Docter,Meg LaFauve', u'Mindy Kaling,Diane Lane'), (2015, 5, u'Furious 7', 353007020, u'James Wan', u'Chris Morgan', u"Tony Jaa,Vin Diesel,Paul Walker,Dwayne Johnson,Michelle Rodriguez,Tyrese Gibson
# ...

# %%
#BoxOffice搜尋
import pyodbc
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.68.48;DATABASE=FB_IMDB;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from [BoxOffice]    ")
BoxOfficerows = cursor.fetchall()

print BoxOfficerows

# %%
#BoxOffice搜尋
import pyodbc
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=163.14.68.48;DATABASE=FB_Bill;UID=sa;PWD=scucc')
cursor = conn.cursor()
cursor.execute("select * from moviedata   ")
BoxOfficerows2 = cursor.fetchall()

print BoxOfficerows2[2][1]
# Out:
# The Giver

# %%
MovieTraier=[]

for BoxOfficerow in BoxOfficerows2:
    MoveiName=BoxOfficerow[1]
    
    for row in rows:
        Title=row[2]
        
        if MoveiName in Title:
            MovieTraier.append( MoveiName)
            break
            
print MovieTraier
print len(MovieTraier)
# Out:
# [u'The Secret Life of Walter Mitty', u'Jurassic World', u'The Giver', u'42', u'Sin City: A Dame to Kill For', u'Ant-Man', u'The Croods', u'Man of Steel', u'World War Z', u'Godzilla', u'Epic', u'The Wolf of Wall Street', u'Poltergeist', u'Goosebumps', u'Seventh Son', u'A Walk in the Woods', u'Jack Ryan: Shadow Recruit', u'Out of the Furnace', u'The Lone Ranger', u'Escape Plan', u'RoboCop', u'Broken City', u'Aloha', u'300: Rise of an Empire', u'Hercules', u'2 Guns', u'Evil Dead', u'Teenage Mutant Ninja Turtles', u'Iron Man 3', u'Bullet to the Head', u'Gangster Squad', u'Terminator: Genisys', u'The Great Gatsby', u'Jack the Giant Slayer', u'Black Mass', u'In the Heart of the Sea', u'Mad Max: Fury Road', u'Prisoners', u'Straight Outta Compton', u'Star Trek Into Darkness', u'Ride Along', u'Paranoia', u'I, Frankenstein', u'The Wolverine', u'Monsters University', u'Gravity', u'The Conjuring', u'Oblivion', u'The Lego Movie', u'The Host', u'Vacation', u"Daddy's Home", u'Elysium', u'Captain Ph
# ...

# %%
from stemming.porter2 import stem

# %%
#意見 正負表
f = open('D:/DOWNLOAD/opinion-lexicon-English/negative-words.txt', 'r')
N = f.read()
f.close()
f = open('D:/DOWNLOAD/opinion-lexicon-English/positive-words.txt', 'r')
P = f.read()
f.close()

PArray=P.split("\n")   
Array=N.split("\n")   
   

NegArray=Array[35:]
PosArray=PArray[35:]
print PosArray
# print NegArray
# Out:
# ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation', 'accolade', 'accolades', 'accommodative', 'accomodative', 'accomplish', 'accomplished', 'accomplishment', 'accomplishments', 'accurate', 'accurately', 'achievable', 'achievement', 'achievements', 'achievible', 'acumen', 'adaptable', 'adaptive', 'adequate', 'adjustable', 'admirable', 'admirably', 'admiration', 'admire', 'admirer', 'admiring', 'admiringly', 'adorable', 'adore', 'adored', 'adorer', 'adoring', 'adoringly', 'adroit', 'adroitly', 'adulate', 'adulation', 'adulatory', 'advanced', 'advantage', 'advantageous', 'advantageously', 'advantages', 'adventuresome', 'adventurous', 'advocate', 'advocated', 'advocates', 'affability', 'affable', 'affably', 'affectation', 'affection', 'affectionate', 'affinity', 'affirm', 'affirmation', 'affirmative', 'affluence', 'affluent', 'afford', 'affordable', 'affordably', 'afordable', 'agile', 'agilely', 'agility', 'agreeable', '
# ...

# %%
print 1
# Out:
# 1
